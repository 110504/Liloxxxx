# %% [markdown]
# <a href="https://colab.research.google.com/github/110504/Liloxxxx/blob/main/Copy_of_Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama : Bertilia Tuto Ola
#
# NIM : H081221024
#
# Meta Stock Price Technical Indicators

# %%
import pandas as pd
dataset = '/content/meta_2014_2023.csv'
data = pd.read_csv(dataset)
data
# Out:
#             date        open        high         low       close    volume  \
# 0     2014-01-02   54.830002   55.220001   54.189999   54.709999  43195500
# 1     2014-01-03   55.020000   55.650002   54.529999   54.560001  38246200
# 2     2014-01-06   54.419998   57.259998   54.049999   57.200001  68852600
# 3     2014-01-07   57.700001   58.549999   57.220001   57.919998  77207400
# 4     2014-01-08   57.599998   58.410000   57.230000   58.230000  56682400
# ...          ...         ...         ...         ...         ...       ...
# 2511  2023-12-22  355.579987  357.200012  351.220001  353.390015  11764200
# 2512  2023-12-26  354.989990  356.980011  353.450012  354.829987   9898600
# 2513  2023-12-27  356.070007  359.000000  355.309998  357.829987  13207900
# 2514  2023-12-28  359.700012  361.899994  357.809998  358.320007  11798800
# 2515  2023-12-29  358.989990  360.000000  351.820007  353.959991  14980500
#
# ...

# %%
data.head(10)
# Out:
#          date       open       high        low      close    volume  \
# 0  2014-01-02  54.830002  55.220001  54.189999  54.709999  43195500
# 1  2014-01-03  55.020000  55.650002  54.529999  54.560001  38246200
# 2  2014-01-06  54.419998  57.259998  54.049999  57.200001  68852600
# 3  2014-01-07  57.700001  58.549999  57.220001  57.919998  77207400
# 4  2014-01-08  57.599998  58.410000  57.230000  58.230000  56682400
# 5  2014-01-09  58.650002  58.959999  56.650002  57.220001  92253300
# 6  2014-01-10  57.130001  58.299999  57.060001  57.939999  42449500
# 7  2014-01-13  57.910000  58.250000  55.380001  55.910000  63010900
# 8  2014-01-14  56.459999  57.779999  56.099998  57.740002  37503600
# 9  2014-01-15  57.980000  58.570000  57.270000  57.599998  33663400
#
#        rsi_7     rsi_14       cci_7      cci_14   sma_50     ema_50  sma_100  \
# 0  51.917475  58.077822  -64.312117  -13.517101  50.2818  50.740946  47.6654
# ...

# %%
print(data.dtypes)
# Out:
# date               object
# open              float64
# high              float64
# low               float64
# close             float64
# volume              int64
# rsi_7             float64
# rsi_14            float64
# cci_7             float64
# cci_14            float64
# sma_50            float64
# ema_50            float64
# sma_100           float64
# ema_100           float64
# macd              float64
# bollinger         float64
# TrueRange         float64
# atr_7             float64
# atr_14            float64
# next_day_close    float64
# dtype: object

# %% [markdown]
# Memangkas Kolom

# %%
datanoid = data.drop(data.columns[19],axis=1)
datanoid
# Out:
#             date        open        high         low       close    volume  \
# 0     2014-01-02   54.830002   55.220001   54.189999   54.709999  43195500
# 1     2014-01-03   55.020000   55.650002   54.529999   54.560001  38246200
# 2     2014-01-06   54.419998   57.259998   54.049999   57.200001  68852600
# 3     2014-01-07   57.700001   58.549999   57.220001   57.919998  77207400
# 4     2014-01-08   57.599998   58.410000   57.230000   58.230000  56682400
# ...          ...         ...         ...         ...         ...       ...
# 2511  2023-12-22  355.579987  357.200012  351.220001  353.390015  11764200
# 2512  2023-12-26  354.989990  356.980011  353.450012  354.829987   9898600
# 2513  2023-12-27  356.070007  359.000000  355.309998  357.829987  13207900
# 2514  2023-12-28  359.700012  361.899994  357.809998  358.320007  11798800
# 2515  2023-12-29  358.989990  360.000000  351.820007  353.959991  14980500
#
# ...

# %% [markdown]
# Deskripsi Data

# %%
data.describe()
# Out:
#               open         high          low        close        volume  \
# count  2516.000000  2516.000000  2516.000000  2516.000000  2.516000e+03
# mean    178.035517   180.328621   175.826359   178.129122  2.617010e+07
# std      81.123720    82.200952    80.118216    81.166653  1.782460e+07
# min      54.020000    54.939999    51.849998    53.529999  5.467500e+06
# 25%     115.787498   117.452497   114.007502   115.565003  1.563175e+07
# 50%     170.114998   172.110001   168.224998   170.245002  2.106275e+07
# 75%     220.297504   221.827499   216.492501   219.864994  3.022008e+07
# max     381.679993   384.329987   378.809998   382.179993  2.323166e+08
#
#              rsi_7       rsi_14        cci_7       cci_14       sma_50  \
# count  2516.000000  2516.000000  2516.000000  2516.000000  2516.000000
# mean     54.339039    54.047585    13.860957    21.786028   175.350939
# std      15.808831    11.486580    99.506607   107.431270    79.621484
# ...

# %% [markdown]
# menghitung korelasi

# %%
data.loc[:,"rsi_7":].corr()
# Out:
#                    rsi_7    rsi_14     cci_7    cci_14    sma_50    ema_50  \
# rsi_7           1.000000  0.934452  0.805269  0.913674 -0.094280 -0.081965
# rsi_14          0.934452  1.000000  0.631383  0.809794 -0.113776 -0.094719
# cci_7           0.805269  0.631383  1.000000  0.833314 -0.051576 -0.049302
# cci_14          0.913674  0.809794  0.833314  1.000000 -0.068108 -0.060653
# sma_50         -0.094280 -0.113776 -0.051576 -0.068108  1.000000  0.999022
# ema_50         -0.081965 -0.094719 -0.049302 -0.060653  0.999022  1.000000
# sma_100        -0.120899 -0.165445 -0.061656 -0.086770  0.986350  0.986472
# ema_100        -0.110719 -0.145077 -0.058944 -0.080500  0.991385  0.992116
# macd            0.544342  0.737057  0.207993  0.408872 -0.011318  0.017994
# bollinger      -0.053725 -0.042235 -0.042045 -0.043926  0.991430  0.994540
# TrueRange      -0.171648 -0.196951 -0.121865 -0.149079  0.560792  0.561830
# ...

# %%
from matplotlib import pyplot as plt
data.plot(kind='scatter', x='rsi_7', y='rsi_14', s=20, alpha=.5)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# Menggunakan API

# %%
# !pip install kaggle

# %%
import os
from google.colab import files

# Pastikan file kaggle.json sudah diunggah
if not os.path.exists("/root/.kaggle/kaggle.json"):
    uploaded = files.upload()
    for fn in uploaded.keys():
        print('User uploaded file "{name}" with length {length} bytes'.format(
            name=fn, length=len(uploaded[fn])))
    # Pindahkan file kaggle.json ke direktori yang tepat
    # !mkdir -p ~/.kaggle
    # !mv kaggle.json ~/.kaggle/
    # !chmod 600 /root/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-9dbcc802-600f-47ca-9a90-854fdd66993d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9dbcc802-600f-47ca-9a90-854fdd66993d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !kaggle datasets list -s "meta stock" -s "technical indicators" -s "financial time series"
# Out:
# ...
# ref                                                             title                                                size  lastUpdated          downloadCount  voteCount  usabilityRating
# --------------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# shebrahimi/financial-distress                                   Financial Distress Prediction                       815KB  2017-12-15 06:23:25          11094        236  0.8235294
# praxitelisk/financial-time-series-datasets                      Financial time series datasets                      147KB  2019-07-06 20:03:30            979         15  0.3529412
# andrewmvd/sp-500-stocks                                         S&P 500 Stocks (daily updated)                       42MB  2024-03-02 00:18:07          15942        311  1.0
# ...

# %%
# !kaggle datasets download shebrahimi/financial-distress
# Out:
# ...
# 100% 815k/815k [00:00<00:00, 1.25MB/s]
# 100% 815k/815k [00:00<00:00, 1.25MB/s]

# %%
# !unzip /content/financial-distress.zip
# Out:
# Archive:  /content/financial-distress.zip
#   inflating: Financial Distress.csv

# %%
pd.read_csv('/content/Financial Distress.csv')
# Out:
#       Company  Time  Financial Distress      x1        x2       x3       x4  \
# 0           1     1            0.010636  1.2810  0.022934  0.87454  1.21640
# 1           1     2           -0.455970  1.2700  0.006454  0.82067  1.00490
# 2           1     3           -0.325390  1.0529 -0.059379  0.92242  0.72926
# 3           1     4           -0.566570  1.1131 -0.015229  0.85888  0.80974
# 4           2     1            1.357300  1.0623  0.107020  0.81460  0.83593
# ...       ...   ...                 ...     ...       ...      ...      ...
# 3667      422    10            0.438020  2.2605  0.202890  0.16037  0.18588
# 3668      422    11            0.482410  1.9615  0.216440  0.20095  0.21642
# 3669      422    12            0.500770  1.7099  0.207970  0.26136  0.21399
# 3670      422    13            0.611030  1.5590  0.185450  0.30728  0.19307
# 3671      422    14            0.518650  1.6148  0.176760  0.36369  0.18442
#
# ...

# %%
# !kaggle datasets download praxitelisk/financial-time-series-datasets
# Out:
# ...
# 100% 147k/147k [00:00<00:00, 483kB/s]
# 100% 147k/147k [00:00<00:00, 482kB/s]

# %%
# !unzip /content/financial-time-series-datasets.zip
# Out:
# Archive:  /content/financial-time-series-datasets.zip
#   inflating: data/AMZN.csv
#   inflating: data/CME_HO1.csv
#   inflating: data/CME_NG1.csv
#   inflating: data/DJI.csv
#   inflating: data/HRB.csv
#   inflating: data/MSFT.csv
#   inflating: data/Sprint_Intraday.txt
#   inflating: financial time series datasets/data/AMZN.csv
#   inflating: financial time series datasets/data/CME_HO1.csv
#   inflating: financial time series datasets/data/CME_NG1.csv
#   inflating: financial time series datasets/data/DJI.csv
#   inflating: financial time series datasets/data/HRB.csv
#   inflating: financial time series datasets/data/MSFT.csv
#   inflating: financial time series datasets/data/Sprint_Intraday.txt

# %%
pd.read_csv('/content/data/CME_HO1.csv')
# Out:
#             Date   Close
# 0     12/30/2005  1.7280
# 1     12/29/2005  1.7030
# 2     12/28/2005  1.6825
# 3     12/27/2005  1.6370
# 4     12/23/2005  1.7053
# ...          ...     ...
# 3749    1/8/1991  0.7430
# 3750    1/7/1991  0.7617
# 3751    1/4/1991  0.6830
# 3752    1/3/1991  0.7024
# 3753    1/2/1991  0.7330
#
# [3754 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Close'].plot(kind='hist', bins=20, title='Close')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
# ...
